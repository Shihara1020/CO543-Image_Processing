# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("cats.jpg")
print(img[100:105, 100:105])
plt.imshow(img[:, :, ::-1])
plt.show()
# Out:
# [[[16 78 54]
#   [16 70 47]
#   [28 67 46]
#   [42 70 50]
#   [48 76 53]]
#
#  [[12 68 45]
#   [11 60 38]
#   [22 61 39]
#   [35 66 45]
#   [38 65 45]]
#
#  [[13 67 44]
#   [ 8 62 39]
#   [12 59 37]
#   [21 62 41]
#   [36 68 49]]
#
#  [[16 70 47]
#   [11 67 44]
#   [ 7 63 40]
#   [11 63 40]
#   [42 81 60]]
#
#  [[ 0 50 26]
#   [ 3 58 33]
#   [ 6 68 44]
#   [21 79 55]
#   [44 86 68]]]
